# %%
# Tensorflow and Keras
from tensorflow import keras
import pandas as pd
#Numpy and MPL
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
(X_train_full, Y_train_full), (X_test, Y_test) = keras.datasets.mnist.load_data()

print(X_train_full.shape)
print(Y_train_full.shape)

X_valid, X_train = X_train_full[:5000]/255.0, X_train_full[5000:]/255.0
Y_valid, Y_train = Y_train_full[:5000], Y_train_full[5000:]

X_test = X_test/255.0
# Out:
# (60000, 28, 28)
# (60000,)

# %%
fig, ax = plt.subplots(1, 10, figsize=(10,2))

for i in range(10):
    ax[i].imshow(X_train_full[i])
    ax[i].axis('off')
    plt.subplots_adjust(wspace=1) 

plt.show()

# %%
checkpoint = keras.callbacks.ModelCheckpoint("dense_model_mnist.h5", save_best_only=True)
early_stopping = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
reduceLr = keras.callbacks.ReduceLROnPlateau()

model = keras.Sequential([
  keras.layers.Flatten(input_shape=[28, 28]),
  keras.layers.BatchNormalization(),
  keras.layers.Dense(75, activation='elu', kernel_initializer="he_normal"),
    
  keras.layers.Dense(50, activation='relu'),
  keras.layers.BatchNormalization(),
  keras.layers.Dropout(0.1),
    
  keras.layers.Dense(25, activation='relu'),
  keras.layers.BatchNormalization(),
  keras.layers.Dropout(0.1),

  keras.layers.Dense(10, activation='softmax')
])


model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Nadam(learning_rate=1e-4),
              metrics=["accuracy"])

history = model.fit(X_train, 
                    Y_train, 
                    epochs=10, 
                    validation_data=(X_valid, Y_valid),
                    callbacks=[checkpoint, early_stopping, reduceLr])
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 23s 12ms/step - loss: 0.9962 - accuracy: 0.7088 - val_loss: 0.4114 - val_accuracy: 0.8936
# Epoch 2/10
# 1719/1719 [==============================] - 21s 12ms/step - loss: 0.4572 - accuracy: 0.8767 - val_loss: 0.2566 - val_accuracy: 0.9276
# Epoch 3/10
# 1719/1719 [==============================] - 21s 12ms/step - loss: 0.3423 - accuracy: 0.9043 - val_loss: 0.2028 - val_accuracy: 0.9422
# Epoch 4/10
# 1719/1719 [==============================] - 21s 12ms/step - loss: 0.2841 - accuracy: 0.9193 - val_loss: 0.1776 - val_accuracy: 0.9482
# Epoch 5/10
# 1719/1719 [==============================] - 21s 12ms/step - loss: 0.2462 - accuracy: 0.9291 - val_loss: 0.1611 - val_accuracy: 0.9526
# Epoch 6/10
# 1719/1719 [==============================] - 21s 12ms/step - loss: 0.2223 - accuracy: 0.9349 - val_loss: 0.1486 - val_accuracy: 0.9540
# Epoch 7/10
# 1719/1719 [==============================] - 21s 12ms/step - loss: 0.2010 - accuracy: 0.9413 - val_loss: 0.1397 - val_accuracy: 0.9574
# Epoch 8/10
# 1719/1719 [==============================] - 21s 12ms/step - loss: 0.1890 - accuracy: 0.9436 - val_loss: 0.1308 - val_accuracy: 0.9600
# Epoch 9/10
# 1719/1719 [==============================] - 21s 12ms/step - loss: 0.1784 - accuracy: 0.9466 - val_loss: 0.1268 - val_accuracy: 0.9612
# Epoch 10/10
# 1719/1719 [==============================] - 21s 12ms/step - loss: 0.1683 - accuracy: 0.9499 - val_loss: 0.1218 - val_accuracy: 0.9628

# %%
pd.DataFrame(history.history).plot()
plt.show()

model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1305 - accuracy: 0.9634
# [0.13048604130744934, 0.9634000062942505]

# %%
(X_train_cifar10, Y_train_cifar10), (X_test_cifar10, Y_test_cifar10) = keras.datasets.cifar10.load_data()

print(X_train_cifar10.shape)
print(Y_train_cifar10.shape)

X_valid_cifar10, X_train_cifar10 = X_train_cifar10[:5000]/255.0, X_train_cifar10[5000:]/255.0
Y_valid_cifar10, Y_train_cifar10 = Y_train_cifar10[:5000], Y_train_cifar10[5000:]

X_test_cifar10 = X_test_cifar10/255.0
# Out:
# (50000, 32, 32, 3)
# (50000, 1)

# %%
(X_train_cifar100, Y_train_cifar100), (X_test_cifar100, Y_test_cifar100) = keras.datasets.cifar100.load_data()

print(X_train_cifar100.shape)
print(Y_train_cifar100.shape)

X_valid_cifar100, X_train_cifar100 = X_train_cifar100[:5000]/255.0, X_train_cifar100[5000:]/255.0
Y_valid_cifar100, Y_train_cifar100 = Y_train_cifar100[:5000], Y_train_cifar100[5000:]

X_test_cifar100 = X_test_cifar100/255.0
# Out:
# (50000, 32, 32, 3)
# (50000, 1)

# %%
fig, ax = plt.subplots(5, 5, figsize=(10, 10))
ax = ax.ravel()

# Labels come as numbers of [0..9], so here are the class names for humans
class_names = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

for i in range(25):
    ax[i].imshow(X_train_cifar10[i])
    ax[i].set_title(class_names[Y_train_cifar10[i][0]])
    ax[i].axis('off')
    plt.subplots_adjust(wspace=1) 

plt.show()

# %%
checkpoint = keras.callbacks.ModelCheckpoint("simple_dense.h5", save_best_only=True)
early_stopping = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
reduceLr = keras.callbacks.ReduceLROnPlateau()

model = keras.Sequential([
  keras.layers.Flatten(input_shape=[32, 32, 3]),
  keras.layers.BatchNormalization(),
  keras.layers.Dense(75),
    
  keras.layers.Dense((50), activation='elu'),
  keras.layers.BatchNormalization(),
  keras.layers.Dropout(0.1),
    
  keras.layers.Dense((50), activation='elu'),
  keras.layers.BatchNormalization(),
  keras.layers.Dropout(0.1),
    
  keras.layers.Dense(10, activation='softmax')
])

model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(),
              metrics=["accuracy"])

history = model.fit(X_train_cifar10, 
                    Y_train_cifar10, 
                    epochs=60, 
                    validation_data=(X_valid_cifar10, Y_valid_cifar10),
                    callbacks=[checkpoint, early_stopping, reduceLr])
# Out:
# Epoch 1/60
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.8266 - accuracy: 0.3518 - val_loss: 1.5916 - val_accuracy: 0.4312
# Epoch 2/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.6497 - accuracy: 0.4111 - val_loss: 1.5348 - val_accuracy: 0.4490
# Epoch 3/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.5892 - accuracy: 0.4342 - val_loss: 1.4830 - val_accuracy: 0.4696
# Epoch 4/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.5553 - accuracy: 0.4487 - val_loss: 1.4763 - val_accuracy: 0.4750
# Epoch 5/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.5226 - accuracy: 0.4583 - val_loss: 1.4431 - val_accuracy: 0.4838
# Epoch 6/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.4976 - accuracy: 0.4653 - val_loss: 1.4285 - val_accuracy: 0.4904
# Epoch 7/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.4807 - accuracy: 0.4740 - val_loss: 1.4134 - val_accuracy: 0.4996
# Epoch 8/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.4631 - accuracy: 0.4792 - val_loss: 1.3959 - val_accuracy: 0.5140
# Epoch 9/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.4466 - accuracy: 0.4851 - val_loss: 1.3967 - val_accuracy: 0.5066
# Epoch 10/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.4327 - accuracy: 0.4893 - val_loss: 1.3740 - val_accuracy: 0.5160
# Epoch 11/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.4293 - accuracy: 0.4895 - val_loss: 1.3645 - val_accuracy: 0.5200
# Epoch 12/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.4143 - accuracy: 0.4956 - val_loss: 1.3762 - val_accuracy: 0.5150
# Epoch 13/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.4084 - accuracy: 0.4995 - val_loss: 1.3693 - val_accuracy: 0.5122
# Epoch 14/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3983 - accuracy: 0.4970 - val_loss: 1.3666 - val_accuracy: 0.5132
# Epoch 15/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3890 - accuracy: 0.5054 - val_loss: 1.3701 - val_accuracy: 0.5228
# Epoch 16/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3860 - accuracy: 0.5087 - val_loss: 1.3688 - val_accuracy: 0.5230
# Epoch 17/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3801 - accuracy: 0.5066 - val_loss: 1.3626 - val_accuracy: 0.5196
# Epoch 18/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3706 - accuracy: 0.5059 - val_loss: 1.3464 - val_accuracy: 0.5230
# Epoch 19/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3670 - accuracy: 0.5148 - val_loss: 1.3563 - val_accuracy: 0.5226
# Epoch 20/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3591 - accuracy: 0.5128 - val_loss: 1.3451 - val_accuracy: 0.5232
# Epoch 21/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3547 - accuracy: 0.5166 - val_loss: 1.3505 - val_accuracy: 0.5228
# Epoch 22/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3461 - accuracy: 0.5185 - val_loss: 1.3456 - val_accuracy: 0.5284
# Epoch 23/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3470 - accuracy: 0.5209 - val_loss: 1.3349 - val_accuracy: 0.5302
# Epoch 24/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3395 - accuracy: 0.5219 - val_loss: 1.3404 - val_accuracy: 0.5322
# Epoch 25/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3354 - accuracy: 0.5241 - val_loss: 1.3414 - val_accuracy: 0.5336
# Epoch 26/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3309 - accuracy: 0.5252 - val_loss: 1.3379 - val_accuracy: 0.5308
# Epoch 27/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3276 - accuracy: 0.5254 - val_loss: 1.3398 - val_accuracy: 0.5298
# Epoch 28/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3275 - accuracy: 0.5282 - val_loss: 1.3352 - val_accuracy: 0.5292
# Epoch 29/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3156 - accuracy: 0.5300 - val_loss: 1.3433 - val_accuracy: 0.5248
# Epoch 30/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3143 - accuracy: 0.5312 - val_loss: 1.3432 - val_accuracy: 0.5296
# Epoch 31/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3083 - accuracy: 0.5319 - val_loss: 1.3363 - val_accuracy: 0.5348
# Epoch 32/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3080 - accuracy: 0.5344 - val_loss: 1.3381 - val_accuracy: 0.5326
# Epoch 33/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.3017 - accuracy: 0.5366 - val_loss: 1.3283 - val_accuracy: 0.5396
# Epoch 34/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.2971 - accuracy: 0.5365 - val_loss: 1.3362 - val_accuracy: 0.5306
# Epoch 35/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.2972 - accuracy: 0.5370 - val_loss: 1.3361 - val_accuracy: 0.5354
# Epoch 36/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.2945 - accuracy: 0.5374 - val_loss: 1.3283 - val_accuracy: 0.5370
# Epoch 37/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.2887 - accuracy: 0.5399 - val_loss: 1.3306 - val_accuracy: 0.5412
# Epoch 38/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.2810 - accuracy: 0.5421 - val_loss: 1.3305 - val_accuracy: 0.5376
# Epoch 39/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.2823 - accuracy: 0.5432 - val_loss: 1.3355 - val_accuracy: 0.5306
# Epoch 40/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.2776 - accuracy: 0.5443 - val_loss: 1.3321 - val_accuracy: 0.5348
# Epoch 41/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.2720 - accuracy: 0.5471 - val_loss: 1.3377 - val_accuracy: 0.5334
# Epoch 42/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.2774 - accuracy: 0.5461 - val_loss: 1.3364 - val_accuracy: 0.5320
# Epoch 43/60
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.2713 - accuracy: 0.5478 - val_loss: 1.3333 - val_accuracy: 0.5372

# %%
pd.DataFrame(history.history).plot()
plt.show()

model.evaluate(X_test_cifar10, Y_test_cifar10)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.3394 - accuracy: 0.5202
# [1.3394205570220947, 0.5202000141143799]

# %%
checkpoint = keras.callbacks.ModelCheckpoint("bigger_dense.h5", save_best_only=True)
early_stopping = keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)
reduceLr = keras.callbacks.ReduceLROnPlateau()

# Modify the model
model1 = keras.Sequential([
  keras.layers.Flatten(input_shape=[32, 32, 3]),
  keras.layers.BatchNormalization(),
  keras.layers.Dense(256, activation='relu', kernel_initializer="he_normal"),
    
  keras.layers.Dense(128, activation='relu'),
  keras.layers.BatchNormalization(),
  keras.layers.Dropout(0.1),

  keras.layers.Dense(100, activation='softmax')
])


model1.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(),
              metrics=["accuracy"])

history = model1.fit(X_train_cifar100, 
                    Y_train_cifar100, 
                    epochs=50, 
                    validation_data=(X_valid_cifar100, Y_valid_cifar100),
                    callbacks=[checkpoint, early_stopping, reduceLr])
# Out:
# Epoch 1/50
# 1407/1407 [==============================] - 7s 4ms/step - loss: 3.8827 - accuracy: 0.1175 - val_loss: 3.5964 - val_accuracy: 0.1636
# Epoch 2/50
# 1407/1407 [==============================] - 6s 4ms/step - loss: 3.4838 - accuracy: 0.1801 - val_loss: 3.3571 - val_accuracy: 0.1998
# Epoch 3/50
# 1407/1407 [==============================] - 6s 4ms/step - loss: 3.3073 - accuracy: 0.2096 - val_loss: 3.2958 - val_accuracy: 0.2112
# Epoch 4/50
# 1407/1407 [==============================] - 6s 4ms/step - loss: 3.1890 - accuracy: 0.2327 - val_loss: 3.2145 - val_accuracy: 0.2328
# Epoch 5/50
# 1407/1407 [==============================] - 6s 4ms/step - loss: 3.0943 - accuracy: 0.2483 - val_loss: 3.2080 - val_accuracy: 0.2366
# Epoch 6/50
# 1407/1407 [==============================] - 6s 4ms/step - loss: 3.0028 - accuracy: 0.2638 - val_loss: 3.1636 - val_accuracy: 0.2474
# Epoch 7/50
# 1407/1407 [==============================] - 6s 4ms/step - loss: 2.9177 - accuracy: 0.2816 - val_loss: 3.1424 - val_accuracy: 0.2496
# Epoch 8/50
# 1407/1407 [==============================] - 6s 4ms/step - loss: 2.8420 - accuracy: 0.2965 - val_loss: 3.1012 - val_accuracy: 0.2556
# Epoch 9/50
# 1407/1407 [==============================] - 6s 4ms/step - loss: 2.7807 - accuracy: 0.3067 - val_loss: 3.1305 - val_accuracy: 0.2606
# Epoch 10/50
# 1407/1407 [==============================] - 6s 4ms/step - loss: 2.7159 - accuracy: 0.3162 - val_loss: 3.1282 - val_accuracy: 0.2548
# Epoch 11/50
# 1407/1407 [==============================] - 6s 4ms/step - loss: 2.6520 - accuracy: 0.3304 - val_loss: 3.1542 - val_accuracy: 0.2552
# Epoch 12/50
# 1407/1407 [==============================] - 6s 4ms/step - loss: 2.6033 - accuracy: 0.3409 - val_loss: 3.1237 - val_accuracy: 0.2616
# Epoch 13/50
# 1407/1407 [==============================] - 6s 4ms/step - loss: 2.5520 - accuracy: 0.3519 - val_loss: 3.1631 - val_accuracy: 0.2452

# %%
pd.DataFrame(history.history).plot()
plt.show()

model1.evaluate(X_test_cifar100, Y_test_cifar100)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 3.0973 - accuracy: 0.2617
# [3.097311019897461, 0.26170000433921814]

# %%
checkpoint = keras.callbacks.ModelCheckpoint("overcomplicated_cnn_cifar10.h5", save_best_only=True)
early_stopping = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
reduceLr = keras.callbacks.ReduceLROnPlateau()

model = keras.models.Sequential([
    keras.layers.Conv2D(64, 3, activation='relu', padding='same', input_shape=[32, 32, 3]),
    keras.layers.Conv2D(64, 3, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(2),
    keras.layers.BatchNormalization(),
    
    keras.layers.Conv2D(128, 2, activation='relu', padding='same'),
    keras.layers.Conv2D(128, 2, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(2),
    keras.layers.BatchNormalization(),
    
    keras.layers.Conv2D(256, 3, activation='relu', padding='same'),
    keras.layers.Conv2D(256, 3, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(2),
    keras.layers.BatchNormalization(),
    
    keras.layers.Conv2D(512, 3, activation='relu', padding='same'),
    keras.layers.Conv2D(512, 3, activation='relu', padding='same'),
    keras.layers.BatchNormalization(),

    
    keras.layers.Flatten(),    
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(),
              metrics=["accuracy"])

model.summary()

history = model.fit(X_train_cifar10, 
                    Y_train_cifar10, 
                    epochs=50,
                    batch_size=32,
                    validation_data=(X_valid_cifar10, Y_valid_cifar10),
                    callbacks=[checkpoint])
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       32896
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       65664
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 4, 512)         2359808
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                524352
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                650
# =================================================================
# Total params: 5,091,338
# Trainable params: 5,089,418
# Non-trainable params: 1,920
# _________________________________________________________________
# Epoch 1/50
# 1407/1407 [==============================] - 26s 17ms/step - loss: 1.5196 - accuracy: 0.4318 - val_loss: 1.5388 - val_accuracy: 0.4914
# Epoch 2/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.9810 - accuracy: 0.6511 - val_loss: 1.0556 - val_accuracy: 0.6300
# Epoch 3/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.7550 - accuracy: 0.7389 - val_loss: 1.0173 - val_accuracy: 0.6770
# Epoch 4/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.5837 - accuracy: 0.7989 - val_loss: 1.2130 - val_accuracy: 0.6386
# Epoch 5/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.4495 - accuracy: 0.8466 - val_loss: 0.8298 - val_accuracy: 0.7272
# Epoch 6/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.3285 - accuracy: 0.8872 - val_loss: 0.7885 - val_accuracy: 0.7562
# Epoch 7/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.2415 - accuracy: 0.9172 - val_loss: 0.8235 - val_accuracy: 0.7834
# Epoch 8/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.1862 - accuracy: 0.9361 - val_loss: 0.7729 - val_accuracy: 0.7950
# Epoch 9/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.1427 - accuracy: 0.9526 - val_loss: 0.8540 - val_accuracy: 0.7946
# Epoch 10/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.1272 - accuracy: 0.9576 - val_loss: 0.9500 - val_accuracy: 0.7780
# Epoch 11/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.1019 - accuracy: 0.9658 - val_loss: 0.7889 - val_accuracy: 0.8154
# Epoch 12/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0920 - accuracy: 0.9696 - val_loss: 0.8824 - val_accuracy: 0.8012
# Epoch 13/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0859 - accuracy: 0.9723 - val_loss: 0.9113 - val_accuracy: 0.8040
# Epoch 14/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0730 - accuracy: 0.9758 - val_loss: 0.9437 - val_accuracy: 0.8030
# Epoch 15/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0686 - accuracy: 0.9782 - val_loss: 0.8573 - val_accuracy: 0.8188
# Epoch 16/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0622 - accuracy: 0.9804 - val_loss: 1.0147 - val_accuracy: 0.8084
# Epoch 17/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0625 - accuracy: 0.9804 - val_loss: 1.0155 - val_accuracy: 0.7938
# Epoch 18/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0597 - accuracy: 0.9807 - val_loss: 0.9224 - val_accuracy: 0.8264
# Epoch 19/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0483 - accuracy: 0.9841 - val_loss: 1.0223 - val_accuracy: 0.8082
# Epoch 20/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0537 - accuracy: 0.9828 - val_loss: 0.9224 - val_accuracy: 0.8160
# Epoch 21/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0462 - accuracy: 0.9849 - val_loss: 1.1201 - val_accuracy: 0.8036
# Epoch 22/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0504 - accuracy: 0.9838 - val_loss: 1.0702 - val_accuracy: 0.7980
# Epoch 23/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0438 - accuracy: 0.9860 - val_loss: 0.9527 - val_accuracy: 0.8130
# Epoch 24/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0499 - accuracy: 0.9846 - val_loss: 1.0257 - val_accuracy: 0.8072
# Epoch 25/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0359 - accuracy: 0.9882 - val_loss: 1.0554 - val_accuracy: 0.8192
# Epoch 26/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0385 - accuracy: 0.9876 - val_loss: 1.4609 - val_accuracy: 0.7560
# Epoch 27/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0382 - accuracy: 0.9881 - val_loss: 1.0343 - val_accuracy: 0.8234
# Epoch 28/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0384 - accuracy: 0.9878 - val_loss: 0.9474 - val_accuracy: 0.8290
# Epoch 29/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0340 - accuracy: 0.9891 - val_loss: 1.0439 - val_accuracy: 0.8246
# Epoch 30/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0340 - accuracy: 0.9893 - val_loss: 1.3368 - val_accuracy: 0.7832
# Epoch 31/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0408 - accuracy: 0.9878 - val_loss: 1.0277 - val_accuracy: 0.8210
# Epoch 32/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0263 - accuracy: 0.9916 - val_loss: 1.1557 - val_accuracy: 0.8084
# Epoch 33/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0266 - accuracy: 0.9917 - val_loss: 1.0116 - val_accuracy: 0.8262
# Epoch 34/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0281 - accuracy: 0.9906 - val_loss: 1.1108 - val_accuracy: 0.8120
# Epoch 35/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0323 - accuracy: 0.9900 - val_loss: 1.0484 - val_accuracy: 0.8150
# Epoch 36/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0275 - accuracy: 0.9914 - val_loss: 1.1554 - val_accuracy: 0.8278
# Epoch 37/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0282 - accuracy: 0.9918 - val_loss: 1.1778 - val_accuracy: 0.8156
# Epoch 38/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0283 - accuracy: 0.9911 - val_loss: 1.0142 - val_accuracy: 0.8240
# Epoch 39/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0273 - accuracy: 0.9907 - val_loss: 1.0612 - val_accuracy: 0.8338
# Epoch 40/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0235 - accuracy: 0.9925 - val_loss: 1.1061 - val_accuracy: 0.8246
# Epoch 41/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0260 - accuracy: 0.9920 - val_loss: 0.9759 - val_accuracy: 0.8272
# Epoch 42/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0252 - accuracy: 0.9921 - val_loss: 0.9768 - val_accuracy: 0.8350
# Epoch 43/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0212 - accuracy: 0.9931 - val_loss: 1.0268 - val_accuracy: 0.8294
# Epoch 44/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0335 - accuracy: 0.9910 - val_loss: 1.0523 - val_accuracy: 0.8266
# Epoch 45/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0181 - accuracy: 0.9940 - val_loss: 0.9952 - val_accuracy: 0.8406
# Epoch 46/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0201 - accuracy: 0.9936 - val_loss: 1.2490 - val_accuracy: 0.8102
# Epoch 47/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0250 - accuracy: 0.9927 - val_loss: 1.1423 - val_accuracy: 0.8184
# Epoch 48/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0216 - accuracy: 0.9934 - val_loss: 1.1125 - val_accuracy: 0.8218
# Epoch 49/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0195 - accuracy: 0.9942 - val_loss: 1.1467 - val_accuracy: 0.8148
# Epoch 50/50
# 1407/1407 [==============================] - 24s 17ms/step - loss: 0.0208 - accuracy: 0.9940 - val_loss: 1.1171 - val_accuracy: 0.8272

# %%
pd.DataFrame(history.history).plot()
plt.show()

model.evaluate(X_test_cifar10, Y_test_cifar10)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 1.3565 - accuracy: 0.8134
# [1.356466293334961, 0.8133999705314636]

# %%
checkpoint = keras.callbacks.ModelCheckpoint("simplified_cnn_cifar10.h5", save_best_only=True)
early_stopping = keras.callbacks.EarlyStopping(patience=25, restore_best_weights=True)
reduceLr = keras.callbacks.ReduceLROnPlateau()

model = keras.models.Sequential([
    keras.layers.Conv2D(32, 3, activation='relu', padding='same', input_shape=[32, 32, 3]),
    keras.layers.Conv2D(32, 3, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(2),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.4),
    
    keras.layers.Conv2D(64, 2, activation='relu', padding='same'),
    keras.layers.Conv2D(64, 2, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(2),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.2),
    
    keras.layers.Conv2D(128, 3, activation='relu', padding='same'),
    keras.layers.Conv2D(128, 3, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(2),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.2),
    
    keras.layers.Conv2D(256, 3, activation='relu', padding='same'),
    keras.layers.Conv2D(256, 3, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(2),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.2),
    
    keras.layers.Flatten(),    
    keras.layers.Dense(32, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(decay=0.0015),
              metrics=["accuracy"])

model.summary()

history = model.fit(X_train_cifar10, 
                    Y_train_cifar10, 
                    epochs=100,
                    batch_size=32,
                    validation_data=(X_valid_cifar10, Y_valid_cifar10),
                    callbacks=[checkpoint, early_stopping])
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 16, 16, 32)        128
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 16, 16, 64)        8256
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 16, 16, 64)        16448
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 8, 8, 64)          256
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 4, 4, 128)         512
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 4, 4, 256)         295168
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 4, 4, 256)         590080
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 2, 2, 256)         1024
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 32)                32800
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 32)                128
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 10)                330
# =================================================================
# Total params: 1,176,714
# Trainable params: 1,175,690
# Non-trainable params: 1,024
# _________________________________________________________________
# Epoch 1/100
# 1407/1407 [==============================] - 17s 11ms/step - loss: 1.6012 - accuracy: 0.4329 - val_loss: 1.3507 - val_accuracy: 0.5284
# Epoch 2/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 1.1455 - accuracy: 0.6006 - val_loss: 0.9683 - val_accuracy: 0.6600
# Epoch 3/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.9644 - accuracy: 0.6675 - val_loss: 0.8455 - val_accuracy: 0.7034
# Epoch 4/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.8584 - accuracy: 0.7076 - val_loss: 0.7807 - val_accuracy: 0.7242
# Epoch 5/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.7828 - accuracy: 0.7349 - val_loss: 0.7475 - val_accuracy: 0.7362
# Epoch 6/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.7250 - accuracy: 0.7554 - val_loss: 0.7000 - val_accuracy: 0.7584
# Epoch 7/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.6807 - accuracy: 0.7710 - val_loss: 0.6779 - val_accuracy: 0.7668
# Epoch 8/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.6426 - accuracy: 0.7819 - val_loss: 0.6513 - val_accuracy: 0.7780
# Epoch 9/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.6181 - accuracy: 0.7895 - val_loss: 0.6743 - val_accuracy: 0.7668
# Epoch 10/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.5844 - accuracy: 0.8039 - val_loss: 0.5924 - val_accuracy: 0.7920
# Epoch 11/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.5649 - accuracy: 0.8090 - val_loss: 0.6055 - val_accuracy: 0.7898
# Epoch 12/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.5435 - accuracy: 0.8160 - val_loss: 0.6027 - val_accuracy: 0.7874
# Epoch 13/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.5293 - accuracy: 0.8226 - val_loss: 0.6016 - val_accuracy: 0.7934
# Epoch 14/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.5047 - accuracy: 0.8304 - val_loss: 0.5681 - val_accuracy: 0.8054
# Epoch 15/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.4948 - accuracy: 0.8319 - val_loss: 0.6026 - val_accuracy: 0.7944
# Epoch 16/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.4772 - accuracy: 0.8401 - val_loss: 0.5996 - val_accuracy: 0.7928
# Epoch 17/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.4701 - accuracy: 0.8425 - val_loss: 0.5817 - val_accuracy: 0.8004
# Epoch 18/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.4559 - accuracy: 0.8462 - val_loss: 0.5822 - val_accuracy: 0.8028
# Epoch 19/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.4414 - accuracy: 0.8517 - val_loss: 0.5618 - val_accuracy: 0.8080
# Epoch 20/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.4341 - accuracy: 0.8533 - val_loss: 0.5732 - val_accuracy: 0.8048
# Epoch 21/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.4217 - accuracy: 0.8573 - val_loss: 0.5531 - val_accuracy: 0.8100
# Epoch 22/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.4132 - accuracy: 0.8616 - val_loss: 0.5602 - val_accuracy: 0.8124
# Epoch 23/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.4079 - accuracy: 0.8618 - val_loss: 0.5674 - val_accuracy: 0.8074
# Epoch 24/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.4015 - accuracy: 0.8654 - val_loss: 0.5603 - val_accuracy: 0.8120
# Epoch 25/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.3923 - accuracy: 0.8688 - val_loss: 0.5704 - val_accuracy: 0.8084
# Epoch 26/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.3853 - accuracy: 0.8713 - val_loss: 0.5526 - val_accuracy: 0.8140
# Epoch 27/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.3810 - accuracy: 0.8723 - val_loss: 0.5694 - val_accuracy: 0.8112
# Epoch 28/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.3760 - accuracy: 0.8734 - val_loss: 0.5633 - val_accuracy: 0.8116
# Epoch 29/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.3647 - accuracy: 0.8772 - val_loss: 0.5813 - val_accuracy: 0.8066
# Epoch 30/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.3618 - accuracy: 0.8784 - val_loss: 0.5639 - val_accuracy: 0.8110
# Epoch 31/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.3582 - accuracy: 0.8793 - val_loss: 0.5578 - val_accuracy: 0.8138
# Epoch 32/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.3506 - accuracy: 0.8820 - val_loss: 0.5808 - val_accuracy: 0.8070
# Epoch 33/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.3470 - accuracy: 0.8839 - val_loss: 0.5684 - val_accuracy: 0.8118
# Epoch 34/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.3370 - accuracy: 0.8869 - val_loss: 0.5690 - val_accuracy: 0.8126
# Epoch 35/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.3385 - accuracy: 0.8855 - val_loss: 0.5789 - val_accuracy: 0.8058
# Epoch 36/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.3325 - accuracy: 0.8875 - val_loss: 0.5530 - val_accuracy: 0.8150
# Epoch 37/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.3348 - accuracy: 0.8871 - val_loss: 0.5746 - val_accuracy: 0.8106
# Epoch 38/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.3236 - accuracy: 0.8920 - val_loss: 0.5666 - val_accuracy: 0.8130
# Epoch 39/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.3232 - accuracy: 0.8917 - val_loss: 0.5759 - val_accuracy: 0.8128
# Epoch 40/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.3170 - accuracy: 0.8936 - val_loss: 0.5735 - val_accuracy: 0.8124
# Epoch 41/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.3081 - accuracy: 0.8954 - val_loss: 0.5638 - val_accuracy: 0.8148
# Epoch 42/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.3093 - accuracy: 0.8965 - val_loss: 0.5655 - val_accuracy: 0.8164
# Epoch 43/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.3046 - accuracy: 0.8975 - val_loss: 0.5774 - val_accuracy: 0.8120
# Epoch 44/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.3069 - accuracy: 0.8979 - val_loss: 0.5660 - val_accuracy: 0.8176
# Epoch 45/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.2982 - accuracy: 0.9007 - val_loss: 0.5761 - val_accuracy: 0.8132
# Epoch 46/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.2997 - accuracy: 0.8985 - val_loss: 0.5760 - val_accuracy: 0.8118
# Epoch 47/100
# 1407/1407 [==============================] - 16s 11ms/step - loss: 0.2923 - accuracy: 0.9015 - val_loss: 0.5735 - val_accuracy: 0.8160
# Epoch 48/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.2936 - accuracy: 0.9017 - val_loss: 0.5740 - val_accuracy: 0.8158
# Epoch 49/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.2861 - accuracy: 0.9042 - val_loss: 0.5729 - val_accuracy: 0.8130
# Epoch 50/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.2790 - accuracy: 0.9065 - val_loss: 0.5723 - val_accuracy: 0.8134
# Epoch 51/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.2896 - accuracy: 0.9036 - val_loss: 0.5665 - val_accuracy: 0.8196

# %%
pd.DataFrame(history.history).plot()
plt.show()

model.evaluate(X_test_cifar10, Y_test_cifar10)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5981 - accuracy: 0.8082
# [0.5980659127235413, 0.8082000017166138]

# %%
y_preds = model.predict(X_test_cifar10)
print(y_preds[1])
print(np.argmax(y_preds[1]))
# Out:
# [7.9646583e-05 1.4411930e-04 2.1872406e-06 6.1755736e-06 1.3166273e-06
#  4.7640874e-06 7.8607337e-07 6.6647107e-07 9.9975449e-01 5.8065511e-06]
# 8

# %%
fig, ax = plt.subplots(6, 6, figsize=(10, 10))
ax = ax.ravel()

for i in range(0, 36):
    ax[i].imshow(X_test_cifar10[i])
    ax[i].set_title(f"Actual: {class_names[Y_test_cifar10[i][0]]} \nPred: {class_names[np.argmax(y_preds[i])]}")
    ax[i].axis('off')
    plt.subplots_adjust(wspace=1)
    
plt.show()

# %%
checkpoint = keras.callbacks.ModelCheckpoint("overcomplicated_cnn_model_cifar100.h5", save_best_only=True)
early_stopping = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)

model = keras.models.Sequential([
    keras.layers.Conv2D(32, 3, activation='relu', padding='same', input_shape=[32, 32, 3]),
    keras.layers.Conv2D(32, 3, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(2),
    keras.layers.BatchNormalization(),
    
    keras.layers.Conv2D(64, 2, activation='relu', padding='same'),
    keras.layers.Conv2D(64, 2, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(2),
    keras.layers.BatchNormalization(),
    
    keras.layers.Conv2D(128, 3, activation='relu', padding='same'),
    keras.layers.Conv2D(128, 3, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(2),
    keras.layers.BatchNormalization(),
    
    keras.layers.Conv2D(256, 3, activation='relu', padding='same'),
    keras.layers.Conv2D(256, 3, activation='relu', padding='same'),
    keras.layers.BatchNormalization(),
    
    keras.layers.Conv2D(512, 3, activation='relu', padding='same'),
    keras.layers.Conv2D(512, 3, activation='relu', padding='same'),
    keras.layers.BatchNormalization(),
    
    keras.layers.Conv2D(1024, 3, activation='relu', padding='same'),
    keras.layers.Conv2D(1024, 3, activation='relu', padding='same'),
    keras.layers.BatchNormalization(),
    
    keras.layers.Flatten(),    
    keras.layers.Dense(256, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.BatchNormalization(),
    
    keras.layers.Dense(100, activation='softmax')
])

model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(decay=0.0015),
              metrics=["accuracy"])

model.summary()

history = model.fit(X_train_cifar100, Y_train_cifar100, 
                    epochs=50,
                    batch_size=32,
                    validation_data=(X_valid_cifar100, Y_valid_cifar100),
                    callbacks=[checkpoint])
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 16, 16, 32)        128
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 16, 16, 64)        8256
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 16, 16, 64)        16448
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 8, 8, 64)          256
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 4, 4, 128)         512
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 4, 4, 256)         295168
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 4, 4, 256)         590080
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 4, 4, 512)         1180160
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 4, 4, 512)         2359808
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 4, 4, 1024)        4719616
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 4, 4, 1024)        9438208
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 4, 4, 1024)        4096
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               4194560
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 256)               1024
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 128)               512
# _________________________________________________________________
# dense_17 (Dense)             (None, 100)               12900
# =================================================================
# Total params: 23,089,284
# Trainable params: 23,084,484
# Non-trainable params: 4,800
# _________________________________________________________________
# Epoch 1/50
# 1407/1407 [==============================] - 64s 45ms/step - loss: 3.9722 - accuracy: 0.0859 - val_loss: 3.7108 - val_accuracy: 0.1108
# Epoch 2/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 3.3768 - accuracy: 0.1762 - val_loss: 3.2172 - val_accuracy: 0.2096
# Epoch 3/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 2.9360 - accuracy: 0.2594 - val_loss: 2.9948 - val_accuracy: 0.2466
# Epoch 4/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 2.5879 - accuracy: 0.3296 - val_loss: 2.6855 - val_accuracy: 0.3156
# Epoch 5/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 2.3122 - accuracy: 0.3922 - val_loss: 2.5376 - val_accuracy: 0.3444
# Epoch 6/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 2.0503 - accuracy: 0.4504 - val_loss: 2.4762 - val_accuracy: 0.3646
# Epoch 7/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 1.8067 - accuracy: 0.5052 - val_loss: 2.5334 - val_accuracy: 0.3666
# Epoch 8/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 1.5668 - accuracy: 0.5671 - val_loss: 2.5784 - val_accuracy: 0.3670
# Epoch 9/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 1.3443 - accuracy: 0.6238 - val_loss: 2.6402 - val_accuracy: 0.3688
# Epoch 10/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 1.1390 - accuracy: 0.6779 - val_loss: 2.6712 - val_accuracy: 0.3726
# Epoch 11/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.9487 - accuracy: 0.7307 - val_loss: 2.8084 - val_accuracy: 0.3730
# Epoch 12/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.7721 - accuracy: 0.7799 - val_loss: 2.9313 - val_accuracy: 0.3748
# Epoch 13/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.6341 - accuracy: 0.8181 - val_loss: 3.0659 - val_accuracy: 0.3638
# Epoch 14/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.5112 - accuracy: 0.8568 - val_loss: 3.1683 - val_accuracy: 0.3670
# Epoch 15/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.4099 - accuracy: 0.8865 - val_loss: 3.3001 - val_accuracy: 0.3686
# Epoch 16/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.3279 - accuracy: 0.9095 - val_loss: 3.3820 - val_accuracy: 0.3628
# Epoch 17/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.2627 - accuracy: 0.9292 - val_loss: 3.5003 - val_accuracy: 0.3612
# Epoch 18/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.2070 - accuracy: 0.9469 - val_loss: 3.5866 - val_accuracy: 0.3584
# Epoch 19/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.1763 - accuracy: 0.9538 - val_loss: 3.6572 - val_accuracy: 0.3624
# Epoch 20/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.1437 - accuracy: 0.9628 - val_loss: 3.7473 - val_accuracy: 0.3578
# Epoch 21/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.1190 - accuracy: 0.9706 - val_loss: 3.8314 - val_accuracy: 0.3618
# Epoch 22/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.1032 - accuracy: 0.9744 - val_loss: 3.8384 - val_accuracy: 0.3568
# Epoch 23/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0904 - accuracy: 0.9776 - val_loss: 3.9175 - val_accuracy: 0.3616
# Epoch 24/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0793 - accuracy: 0.9810 - val_loss: 3.9547 - val_accuracy: 0.3588
# Epoch 25/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0722 - accuracy: 0.9821 - val_loss: 3.9993 - val_accuracy: 0.3618
# Epoch 26/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0637 - accuracy: 0.9847 - val_loss: 4.0729 - val_accuracy: 0.3640
# Epoch 27/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0566 - accuracy: 0.9865 - val_loss: 4.0973 - val_accuracy: 0.3678
# Epoch 28/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0505 - accuracy: 0.9882 - val_loss: 4.1271 - val_accuracy: 0.3646
# Epoch 29/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0502 - accuracy: 0.9874 - val_loss: 4.1708 - val_accuracy: 0.3646
# Epoch 30/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0420 - accuracy: 0.9899 - val_loss: 4.2090 - val_accuracy: 0.3586
# Epoch 31/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0397 - accuracy: 0.9908 - val_loss: 4.2428 - val_accuracy: 0.3638
# Epoch 32/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0368 - accuracy: 0.9916 - val_loss: 4.2399 - val_accuracy: 0.3686
# Epoch 33/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0344 - accuracy: 0.9919 - val_loss: 4.3237 - val_accuracy: 0.3640
# Epoch 34/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0328 - accuracy: 0.9920 - val_loss: 4.2829 - val_accuracy: 0.3678
# Epoch 35/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0315 - accuracy: 0.9924 - val_loss: 4.3073 - val_accuracy: 0.3700
# Epoch 36/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0283 - accuracy: 0.9934 - val_loss: 4.3240 - val_accuracy: 0.3652
# Epoch 37/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0245 - accuracy: 0.9946 - val_loss: 4.3594 - val_accuracy: 0.3664
# Epoch 38/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0264 - accuracy: 0.9938 - val_loss: 4.4198 - val_accuracy: 0.3620
# Epoch 39/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0244 - accuracy: 0.9942 - val_loss: 4.4414 - val_accuracy: 0.3566
# Epoch 40/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0230 - accuracy: 0.9948 - val_loss: 4.4315 - val_accuracy: 0.3602
# Epoch 41/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0197 - accuracy: 0.9955 - val_loss: 4.4152 - val_accuracy: 0.3728
# Epoch 42/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0218 - accuracy: 0.9945 - val_loss: 4.4460 - val_accuracy: 0.3658
# Epoch 43/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0206 - accuracy: 0.9948 - val_loss: 4.4713 - val_accuracy: 0.3668
# Epoch 44/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0193 - accuracy: 0.9953 - val_loss: 4.4813 - val_accuracy: 0.3670
# Epoch 45/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0164 - accuracy: 0.9961 - val_loss: 4.5000 - val_accuracy: 0.3718
# Epoch 46/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0170 - accuracy: 0.9960 - val_loss: 4.4896 - val_accuracy: 0.3712
# Epoch 47/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0165 - accuracy: 0.9958 - val_loss: 4.5069 - val_accuracy: 0.3702
# Epoch 48/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0148 - accuracy: 0.9967 - val_loss: 4.5277 - val_accuracy: 0.3688
# Epoch 49/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0155 - accuracy: 0.9964 - val_loss: 4.5214 - val_accuracy: 0.3662
# Epoch 50/50
# 1407/1407 [==============================] - 62s 44ms/step - loss: 0.0147 - accuracy: 0.9966 - val_loss: 4.5551 - val_accuracy: 0.3648

# %%
pd.DataFrame(history.history).plot()
plt.show()

model.evaluate(X_test_cifar100, Y_test_cifar100)
# Out:
# 313/313 [==============================] - 4s 12ms/step - loss: 4.4852 - accuracy: 0.3788
# [4.485170841217041, 0.37880000472068787]

# %%
checkpoint = keras.callbacks.ModelCheckpoint("simplified_cnn_model2.h5", save_best_only=True)
early_stopping = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)

model = keras.models.Sequential([
    keras.layers.Conv2D(64, 3, activation='relu', padding='same', input_shape=[32, 32, 3]),
    keras.layers.Conv2D(64, 3, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(2),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.4),
    
    keras.layers.Conv2D(128, 2, activation='relu', padding='same'),
    keras.layers.Conv2D(128, 2, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(2),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.2),
    
    keras.layers.Conv2D(256, 3, activation='relu', padding='same'),
    keras.layers.Conv2D(256, 3, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(2),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.2),
    
    keras.layers.Flatten(),    
    keras.layers.Dense(64, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(100, activation='softmax')
])


model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(decay=0.0015),
              metrics=["accuracy"])

model.summary()

history = model.fit(X_train_cifar100, Y_train_cifar100, 
                    epochs=150,
                    batch_size=32,
                    validation_data=(X_valid_cifar100, Y_valid_cifar100),
                    callbacks=[checkpoint, early_stopping])
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_28 (Conv2D)           (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 32, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 16, 16, 128)       32896
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 16, 16, 128)       65664
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 64)                262208
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 100)               6500
# =================================================================
# Total params: 1,293,284
# Trainable params: 1,292,260
# Non-trainable params: 1,024
# _________________________________________________________________
# Epoch 1/150
# 1407/1407 [==============================] - 18s 12ms/step - loss: 3.8933 - accuracy: 0.1134 - val_loss: 3.4246 - val_accuracy: 0.1896
# Epoch 2/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 3.1612 - accuracy: 0.2362 - val_loss: 2.8869 - val_accuracy: 0.2864
# Epoch 3/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 2.7566 - accuracy: 0.3183 - val_loss: 2.5986 - val_accuracy: 0.3430
# Epoch 4/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 2.4976 - accuracy: 0.3698 - val_loss: 2.3511 - val_accuracy: 0.3906
# Epoch 5/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 2.3306 - accuracy: 0.4040 - val_loss: 2.2491 - val_accuracy: 0.4172
# Epoch 6/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 2.2070 - accuracy: 0.4303 - val_loss: 2.1219 - val_accuracy: 0.4458
# Epoch 7/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 2.1051 - accuracy: 0.4530 - val_loss: 2.0983 - val_accuracy: 0.4492
# Epoch 8/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 2.0218 - accuracy: 0.4720 - val_loss: 2.0084 - val_accuracy: 0.4650
# Epoch 9/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.9455 - accuracy: 0.4882 - val_loss: 1.9855 - val_accuracy: 0.4690
# Epoch 10/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.8842 - accuracy: 0.5010 - val_loss: 1.9802 - val_accuracy: 0.4746
# Epoch 11/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.8299 - accuracy: 0.5117 - val_loss: 1.9911 - val_accuracy: 0.4708
# Epoch 12/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.7823 - accuracy: 0.5227 - val_loss: 1.9380 - val_accuracy: 0.4802
# Epoch 13/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.7457 - accuracy: 0.5305 - val_loss: 1.8994 - val_accuracy: 0.4924
# Epoch 14/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.7139 - accuracy: 0.5395 - val_loss: 1.8893 - val_accuracy: 0.4916
# Epoch 15/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.6750 - accuracy: 0.5498 - val_loss: 1.8990 - val_accuracy: 0.4888
# Epoch 16/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.6475 - accuracy: 0.5539 - val_loss: 1.9025 - val_accuracy: 0.4934
# Epoch 17/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.6147 - accuracy: 0.5615 - val_loss: 1.8894 - val_accuracy: 0.4948
# Epoch 18/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.5866 - accuracy: 0.5705 - val_loss: 1.8620 - val_accuracy: 0.5008
# Epoch 19/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.5658 - accuracy: 0.5755 - val_loss: 1.8651 - val_accuracy: 0.4974
# Epoch 20/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.5375 - accuracy: 0.5787 - val_loss: 1.8577 - val_accuracy: 0.5032
# Epoch 21/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.5221 - accuracy: 0.5818 - val_loss: 1.8734 - val_accuracy: 0.4996
# Epoch 22/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.4958 - accuracy: 0.5923 - val_loss: 1.8361 - val_accuracy: 0.5082
# Epoch 23/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.4761 - accuracy: 0.5972 - val_loss: 1.8398 - val_accuracy: 0.5138
# Epoch 24/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.4617 - accuracy: 0.5980 - val_loss: 1.8377 - val_accuracy: 0.5126
# Epoch 25/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.4394 - accuracy: 0.6040 - val_loss: 1.8482 - val_accuracy: 0.5068
# Epoch 26/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.4330 - accuracy: 0.6058 - val_loss: 1.8334 - val_accuracy: 0.5074
# Epoch 27/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.4087 - accuracy: 0.6104 - val_loss: 1.8371 - val_accuracy: 0.5076
# Epoch 28/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.3956 - accuracy: 0.6160 - val_loss: 1.8334 - val_accuracy: 0.5076
# Epoch 29/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.3770 - accuracy: 0.6178 - val_loss: 1.8224 - val_accuracy: 0.5136
# Epoch 30/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.3689 - accuracy: 0.6188 - val_loss: 1.8461 - val_accuracy: 0.5094
# Epoch 31/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.3512 - accuracy: 0.6248 - val_loss: 1.8173 - val_accuracy: 0.5156
# Epoch 32/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.3360 - accuracy: 0.6294 - val_loss: 1.8504 - val_accuracy: 0.5124
# Epoch 33/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.3313 - accuracy: 0.6288 - val_loss: 1.8240 - val_accuracy: 0.5142
# Epoch 34/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.3082 - accuracy: 0.6379 - val_loss: 1.8229 - val_accuracy: 0.5156
# Epoch 35/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.3065 - accuracy: 0.6366 - val_loss: 1.8359 - val_accuracy: 0.5104
# Epoch 36/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.2936 - accuracy: 0.6363 - val_loss: 1.8061 - val_accuracy: 0.5166
# Epoch 37/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.2879 - accuracy: 0.6410 - val_loss: 1.8279 - val_accuracy: 0.5118
# Epoch 38/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.2790 - accuracy: 0.6446 - val_loss: 1.8123 - val_accuracy: 0.5200
# Epoch 39/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.2650 - accuracy: 0.6446 - val_loss: 1.8282 - val_accuracy: 0.5164
# Epoch 40/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.2506 - accuracy: 0.6499 - val_loss: 1.8242 - val_accuracy: 0.5154
# Epoch 41/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.2378 - accuracy: 0.6523 - val_loss: 1.8155 - val_accuracy: 0.5144
# Epoch 42/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.2321 - accuracy: 0.6504 - val_loss: 1.8173 - val_accuracy: 0.5206
# Epoch 43/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.2208 - accuracy: 0.6565 - val_loss: 1.8077 - val_accuracy: 0.5212
# Epoch 44/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.2155 - accuracy: 0.6554 - val_loss: 1.8294 - val_accuracy: 0.5174
# Epoch 45/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.2033 - accuracy: 0.6623 - val_loss: 1.8187 - val_accuracy: 0.5200
# Epoch 46/150
# 1407/1407 [==============================] - 17s 12ms/step - loss: 1.2040 - accuracy: 0.6596 - val_loss: 1.8190 - val_accuracy: 0.5216

# %%
model.evaluate(X_test_cifar100, Y_test_cifar100)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 1.7632 - accuracy: 0.5283
# [1.7632451057434082, 0.5282999873161316]

# %%
pd.DataFrame(history.history).plot()
plt.show()

model.evaluate(X_test_cifar100, Y_test_cifar100)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 1.7632 - accuracy: 0.5283
# [1.7632451057434082, 0.5282999873161316]

# %%
Y_train_cifar100 = keras.utils.to_categorical(Y_train_cifar100, 100)
Y_valid_cifar100 = keras.utils.to_categorical(Y_valid_cifar100, 100)
Y_test_cifar100 = keras.utils.to_categorical(Y_test_cifar100, 100)

# %%
train_datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)

valid_datagen = ImageDataGenerator()
test_datagen = ImageDataGenerator()

train_generator = train_datagen.flow(X_train_cifar100, Y_train_cifar100, batch_size=32)
valid_generator = valid_datagen.flow(X_valid_cifar100, Y_valid_cifar100, batch_size=32)
test_generator = test_datagen.flow(X_test_cifar100, Y_test_cifar100, batch_size=32)

# %%
checkpoint = keras.callbacks.ModelCheckpoint("augmented_cnn_model2.h5", save_best_only=True)
early_stopping = keras.callbacks.EarlyStopping(patience=25, restore_best_weights=True)
reduceLr = keras.callbacks.ReduceLROnPlateau()

model = keras.models.Sequential([
    keras.layers.Conv2D(64, 3, activation='relu', padding='same', input_shape=[32, 32, 3]),
    keras.layers.Conv2D(64, 3, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(2),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.2),
    
    keras.layers.Conv2D(128, 2, activation='relu', padding='same'),
    keras.layers.Conv2D(128, 2, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(2),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.2),
    
    keras.layers.Conv2D(256, 3, activation='relu', padding='same'),
    keras.layers.Conv2D(256, 3, activation='relu', padding='same'),
    keras.layers.MaxPooling2D(2),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.2),
    
    keras.layers.Flatten(),    
    keras.layers.Dense(64, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(100, activation='softmax')
]) 


model.compile(loss="categorical_crossentropy",
              optimizer=keras.optimizers.Adam(),
              metrics=["accuracy", keras.metrics.TopKCategoricalAccuracy(k=3)])

model.summary()

history = model.fit(train_generator, 
                    epochs=150,
                    validation_data=valid_generator,
                    callbacks=[checkpoint, early_stopping, reduceLr])
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_34 (Conv2D)           (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 32, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 16, 16, 128)       32896
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 16, 16, 128)       65664
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_20 (Dense)             (None, 64)                262208
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_21 (Dense)             (None, 100)               6500
# =================================================================
# Total params: 1,293,284
# Trainable params: 1,292,260
# Non-trainable params: 1,024
# _________________________________________________________________
# Epoch 1/150
# 1407/1407 [==============================] - 19s 13ms/step - loss: 3.8945 - accuracy: 0.1109 - top_k_categorical_accuracy: 0.2332 - val_loss: 3.2462 - val_accuracy: 0.2130 - val_top_k_categorical_accuracy: 0.3974
# Epoch 2/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 3.1708 - accuracy: 0.2230 - top_k_categorical_accuracy: 0.4092 - val_loss: 3.0835 - val_accuracy: 0.2458 - val_top_k_categorical_accuracy: 0.4258
# Epoch 3/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 2.7845 - accuracy: 0.2985 - top_k_categorical_accuracy: 0.5049 - val_loss: 2.7642 - val_accuracy: 0.3088 - val_top_k_categorical_accuracy: 0.5154
# Epoch 4/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 2.5473 - accuracy: 0.3440 - top_k_categorical_accuracy: 0.5626 - val_loss: 2.4782 - val_accuracy: 0.3584 - val_top_k_categorical_accuracy: 0.5718
# Epoch 5/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 2.3789 - accuracy: 0.3822 - top_k_categorical_accuracy: 0.6010 - val_loss: 2.1449 - val_accuracy: 0.4282 - val_top_k_categorical_accuracy: 0.6526
# Epoch 6/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 2.2546 - accuracy: 0.4059 - top_k_categorical_accuracy: 0.6289 - val_loss: 2.1006 - val_accuracy: 0.4454 - val_top_k_categorical_accuracy: 0.6636
# Epoch 7/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 2.1607 - accuracy: 0.4304 - top_k_categorical_accuracy: 0.6518 - val_loss: 2.0164 - val_accuracy: 0.4576 - val_top_k_categorical_accuracy: 0.6778
# Epoch 8/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 2.0681 - accuracy: 0.4479 - top_k_categorical_accuracy: 0.6718 - val_loss: 1.8433 - val_accuracy: 0.4988 - val_top_k_categorical_accuracy: 0.7150
# Epoch 9/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 2.0001 - accuracy: 0.4648 - top_k_categorical_accuracy: 0.6888 - val_loss: 1.9702 - val_accuracy: 0.4684 - val_top_k_categorical_accuracy: 0.6904
# Epoch 10/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.9403 - accuracy: 0.4762 - top_k_categorical_accuracy: 0.6986 - val_loss: 1.9197 - val_accuracy: 0.4726 - val_top_k_categorical_accuracy: 0.7044
# Epoch 11/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.8878 - accuracy: 0.4904 - top_k_categorical_accuracy: 0.7110 - val_loss: 1.7158 - val_accuracy: 0.5292 - val_top_k_categorical_accuracy: 0.7404
# Epoch 12/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.8326 - accuracy: 0.5013 - top_k_categorical_accuracy: 0.7211 - val_loss: 1.6809 - val_accuracy: 0.5372 - val_top_k_categorical_accuracy: 0.7510
# Epoch 13/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.8008 - accuracy: 0.5124 - top_k_categorical_accuracy: 0.7289 - val_loss: 1.6334 - val_accuracy: 0.5510 - val_top_k_categorical_accuracy: 0.7632
# Epoch 14/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.7557 - accuracy: 0.5185 - top_k_categorical_accuracy: 0.7397 - val_loss: 1.6447 - val_accuracy: 0.5394 - val_top_k_categorical_accuracy: 0.7548
# Epoch 15/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.7145 - accuracy: 0.5273 - top_k_categorical_accuracy: 0.7460 - val_loss: 1.6522 - val_accuracy: 0.5410 - val_top_k_categorical_accuracy: 0.7534
# Epoch 16/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.6856 - accuracy: 0.5390 - top_k_categorical_accuracy: 0.7524 - val_loss: 1.5740 - val_accuracy: 0.5634 - val_top_k_categorical_accuracy: 0.7708
# Epoch 17/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.6407 - accuracy: 0.5464 - top_k_categorical_accuracy: 0.7621 - val_loss: 1.7983 - val_accuracy: 0.5318 - val_top_k_categorical_accuracy: 0.7366
# Epoch 18/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.6067 - accuracy: 0.5542 - top_k_categorical_accuracy: 0.7690 - val_loss: 1.6257 - val_accuracy: 0.5568 - val_top_k_categorical_accuracy: 0.7644
# Epoch 19/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.5860 - accuracy: 0.5604 - top_k_categorical_accuracy: 0.7725 - val_loss: 1.5658 - val_accuracy: 0.5694 - val_top_k_categorical_accuracy: 0.7714
# Epoch 20/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.5700 - accuracy: 0.5625 - top_k_categorical_accuracy: 0.7752 - val_loss: 1.6210 - val_accuracy: 0.5550 - val_top_k_categorical_accuracy: 0.7652
# Epoch 21/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.5384 - accuracy: 0.5708 - top_k_categorical_accuracy: 0.7814 - val_loss: 1.5947 - val_accuracy: 0.5724 - val_top_k_categorical_accuracy: 0.7724
# Epoch 22/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.5236 - accuracy: 0.5773 - top_k_categorical_accuracy: 0.7875 - val_loss: 1.5837 - val_accuracy: 0.5650 - val_top_k_categorical_accuracy: 0.7672
# Epoch 23/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.5035 - accuracy: 0.5815 - top_k_categorical_accuracy: 0.7884 - val_loss: 1.6721 - val_accuracy: 0.5418 - val_top_k_categorical_accuracy: 0.7574
# Epoch 24/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.4739 - accuracy: 0.5899 - top_k_categorical_accuracy: 0.7937 - val_loss: 1.5085 - val_accuracy: 0.5794 - val_top_k_categorical_accuracy: 0.7868
# Epoch 25/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.4576 - accuracy: 0.5900 - top_k_categorical_accuracy: 0.7984 - val_loss: 1.5234 - val_accuracy: 0.5808 - val_top_k_categorical_accuracy: 0.7832
# Epoch 26/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.4438 - accuracy: 0.5933 - top_k_categorical_accuracy: 0.8013 - val_loss: 1.5389 - val_accuracy: 0.5780 - val_top_k_categorical_accuracy: 0.7756
# Epoch 27/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.4318 - accuracy: 0.5957 - top_k_categorical_accuracy: 0.8034 - val_loss: 1.5393 - val_accuracy: 0.5854 - val_top_k_categorical_accuracy: 0.7794
# Epoch 28/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.4060 - accuracy: 0.6033 - top_k_categorical_accuracy: 0.8072 - val_loss: 1.5261 - val_accuracy: 0.5836 - val_top_k_categorical_accuracy: 0.7824
# Epoch 29/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.3760 - accuracy: 0.6117 - top_k_categorical_accuracy: 0.8136 - val_loss: 1.4922 - val_accuracy: 0.5950 - val_top_k_categorical_accuracy: 0.7890
# Epoch 30/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.3762 - accuracy: 0.6109 - top_k_categorical_accuracy: 0.8143 - val_loss: 1.4631 - val_accuracy: 0.5962 - val_top_k_categorical_accuracy: 0.7992
# Epoch 31/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.3524 - accuracy: 0.6164 - top_k_categorical_accuracy: 0.8181 - val_loss: 1.4324 - val_accuracy: 0.6080 - val_top_k_categorical_accuracy: 0.8010
# Epoch 32/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.3400 - accuracy: 0.6202 - top_k_categorical_accuracy: 0.8206 - val_loss: 1.4539 - val_accuracy: 0.6016 - val_top_k_categorical_accuracy: 0.7936
# Epoch 33/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.3326 - accuracy: 0.6218 - top_k_categorical_accuracy: 0.8218 - val_loss: 1.5187 - val_accuracy: 0.5892 - val_top_k_categorical_accuracy: 0.7880
# Epoch 34/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.3187 - accuracy: 0.6261 - top_k_categorical_accuracy: 0.8222 - val_loss: 1.4526 - val_accuracy: 0.6006 - val_top_k_categorical_accuracy: 0.7986
# Epoch 35/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.3068 - accuracy: 0.6272 - top_k_categorical_accuracy: 0.8276 - val_loss: 1.4437 - val_accuracy: 0.6092 - val_top_k_categorical_accuracy: 0.7998
# Epoch 36/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.2859 - accuracy: 0.6345 - top_k_categorical_accuracy: 0.8317 - val_loss: 1.4499 - val_accuracy: 0.6082 - val_top_k_categorical_accuracy: 0.7968
# Epoch 37/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.2762 - accuracy: 0.6354 - top_k_categorical_accuracy: 0.8322 - val_loss: 1.4703 - val_accuracy: 0.6080 - val_top_k_categorical_accuracy: 0.8002
# Epoch 38/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.2590 - accuracy: 0.6419 - top_k_categorical_accuracy: 0.8359 - val_loss: 1.3732 - val_accuracy: 0.6182 - val_top_k_categorical_accuracy: 0.8132
# Epoch 39/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.2446 - accuracy: 0.6445 - top_k_categorical_accuracy: 0.8388 - val_loss: 1.4785 - val_accuracy: 0.6022 - val_top_k_categorical_accuracy: 0.7996
# Epoch 40/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.2363 - accuracy: 0.6441 - top_k_categorical_accuracy: 0.8403 - val_loss: 1.4025 - val_accuracy: 0.6148 - val_top_k_categorical_accuracy: 0.8100
# Epoch 41/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.2266 - accuracy: 0.6489 - top_k_categorical_accuracy: 0.8406 - val_loss: 1.4115 - val_accuracy: 0.6104 - val_top_k_categorical_accuracy: 0.8070
# Epoch 42/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.2147 - accuracy: 0.6485 - top_k_categorical_accuracy: 0.8450 - val_loss: 1.4451 - val_accuracy: 0.6060 - val_top_k_categorical_accuracy: 0.8032
# Epoch 43/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.2111 - accuracy: 0.6486 - top_k_categorical_accuracy: 0.8454 - val_loss: 1.3705 - val_accuracy: 0.6250 - val_top_k_categorical_accuracy: 0.8176
# Epoch 44/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.1932 - accuracy: 0.6550 - top_k_categorical_accuracy: 0.8477 - val_loss: 1.4076 - val_accuracy: 0.6230 - val_top_k_categorical_accuracy: 0.8134
# Epoch 45/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.1844 - accuracy: 0.6567 - top_k_categorical_accuracy: 0.8516 - val_loss: 1.3393 - val_accuracy: 0.6324 - val_top_k_categorical_accuracy: 0.8222
# Epoch 46/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.1805 - accuracy: 0.6588 - top_k_categorical_accuracy: 0.8501 - val_loss: 1.3645 - val_accuracy: 0.6186 - val_top_k_categorical_accuracy: 0.8158
# Epoch 47/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.1682 - accuracy: 0.6625 - top_k_categorical_accuracy: 0.8531 - val_loss: 1.4387 - val_accuracy: 0.6098 - val_top_k_categorical_accuracy: 0.8028
# Epoch 48/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.1498 - accuracy: 0.6644 - top_k_categorical_accuracy: 0.8556 - val_loss: 1.3654 - val_accuracy: 0.6360 - val_top_k_categorical_accuracy: 0.8182
# Epoch 49/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.1431 - accuracy: 0.6671 - top_k_categorical_accuracy: 0.8589 - val_loss: 1.3937 - val_accuracy: 0.6200 - val_top_k_categorical_accuracy: 0.8104
# Epoch 50/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.1479 - accuracy: 0.6664 - top_k_categorical_accuracy: 0.8577 - val_loss: 1.4091 - val_accuracy: 0.6182 - val_top_k_categorical_accuracy: 0.8094
# Epoch 51/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.1257 - accuracy: 0.6704 - top_k_categorical_accuracy: 0.8604 - val_loss: 1.3614 - val_accuracy: 0.6400 - val_top_k_categorical_accuracy: 0.8144
# Epoch 52/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.1259 - accuracy: 0.6747 - top_k_categorical_accuracy: 0.8605 - val_loss: 1.3756 - val_accuracy: 0.6278 - val_top_k_categorical_accuracy: 0.8138
# Epoch 53/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.1206 - accuracy: 0.6749 - top_k_categorical_accuracy: 0.8621 - val_loss: 1.3330 - val_accuracy: 0.6384 - val_top_k_categorical_accuracy: 0.8296
# Epoch 54/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.1019 - accuracy: 0.6800 - top_k_categorical_accuracy: 0.8632 - val_loss: 1.4526 - val_accuracy: 0.6134 - val_top_k_categorical_accuracy: 0.8100
# Epoch 55/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.0953 - accuracy: 0.6799 - top_k_categorical_accuracy: 0.8655 - val_loss: 1.3483 - val_accuracy: 0.6382 - val_top_k_categorical_accuracy: 0.8294
# Epoch 56/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.1029 - accuracy: 0.6767 - top_k_categorical_accuracy: 0.8624 - val_loss: 1.3410 - val_accuracy: 0.6430 - val_top_k_categorical_accuracy: 0.8232
# Epoch 57/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.0880 - accuracy: 0.6830 - top_k_categorical_accuracy: 0.8693 - val_loss: 1.3812 - val_accuracy: 0.6354 - val_top_k_categorical_accuracy: 0.8214
# Epoch 58/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.0738 - accuracy: 0.6848 - top_k_categorical_accuracy: 0.8700 - val_loss: 1.4282 - val_accuracy: 0.6140 - val_top_k_categorical_accuracy: 0.8066
# Epoch 59/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.0801 - accuracy: 0.6835 - top_k_categorical_accuracy: 0.8682 - val_loss: 1.4685 - val_accuracy: 0.6074 - val_top_k_categorical_accuracy: 0.8008
# Epoch 60/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.0721 - accuracy: 0.6874 - top_k_categorical_accuracy: 0.8701 - val_loss: 1.4573 - val_accuracy: 0.6136 - val_top_k_categorical_accuracy: 0.8146
# Epoch 61/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.0532 - accuracy: 0.6878 - top_k_categorical_accuracy: 0.8740 - val_loss: 1.4101 - val_accuracy: 0.6254 - val_top_k_categorical_accuracy: 0.8162
# Epoch 62/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.0425 - accuracy: 0.6958 - top_k_categorical_accuracy: 0.8753 - val_loss: 1.4127 - val_accuracy: 0.6316 - val_top_k_categorical_accuracy: 0.8154
# Epoch 63/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 1.0410 - accuracy: 0.6937 - top_k_categorical_accuracy: 0.8757 - val_loss: 1.3779 - val_accuracy: 0.6338 - val_top_k_categorical_accuracy: 0.8230
# Epoch 64/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.9669 - accuracy: 0.7140 - top_k_categorical_accuracy: 0.8877 - val_loss: 1.2991 - val_accuracy: 0.6504 - val_top_k_categorical_accuracy: 0.8346
# Epoch 65/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.9265 - accuracy: 0.7267 - top_k_categorical_accuracy: 0.8958 - val_loss: 1.2883 - val_accuracy: 0.6510 - val_top_k_categorical_accuracy: 0.8370
# Epoch 66/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.9162 - accuracy: 0.7278 - top_k_categorical_accuracy: 0.8957 - val_loss: 1.2744 - val_accuracy: 0.6540 - val_top_k_categorical_accuracy: 0.8424
# Epoch 67/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8994 - accuracy: 0.7330 - top_k_categorical_accuracy: 0.8995 - val_loss: 1.2801 - val_accuracy: 0.6538 - val_top_k_categorical_accuracy: 0.8408
# Epoch 68/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8916 - accuracy: 0.7352 - top_k_categorical_accuracy: 0.9005 - val_loss: 1.2751 - val_accuracy: 0.6532 - val_top_k_categorical_accuracy: 0.8402
# Epoch 69/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8778 - accuracy: 0.7388 - top_k_categorical_accuracy: 0.9031 - val_loss: 1.2945 - val_accuracy: 0.6516 - val_top_k_categorical_accuracy: 0.8366
# Epoch 70/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8854 - accuracy: 0.7362 - top_k_categorical_accuracy: 0.9007 - val_loss: 1.2746 - val_accuracy: 0.6566 - val_top_k_categorical_accuracy: 0.8414
# Epoch 71/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8697 - accuracy: 0.7398 - top_k_categorical_accuracy: 0.9024 - val_loss: 1.2693 - val_accuracy: 0.6558 - val_top_k_categorical_accuracy: 0.8428
# Epoch 72/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8663 - accuracy: 0.7422 - top_k_categorical_accuracy: 0.9041 - val_loss: 1.2735 - val_accuracy: 0.6548 - val_top_k_categorical_accuracy: 0.8418
# Epoch 73/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8571 - accuracy: 0.7422 - top_k_categorical_accuracy: 0.9081 - val_loss: 1.2820 - val_accuracy: 0.6560 - val_top_k_categorical_accuracy: 0.8410
# Epoch 74/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8653 - accuracy: 0.7419 - top_k_categorical_accuracy: 0.9038 - val_loss: 1.2749 - val_accuracy: 0.6578 - val_top_k_categorical_accuracy: 0.8414
# Epoch 75/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8561 - accuracy: 0.7433 - top_k_categorical_accuracy: 0.9079 - val_loss: 1.2768 - val_accuracy: 0.6576 - val_top_k_categorical_accuracy: 0.8394
# Epoch 76/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8440 - accuracy: 0.7474 - top_k_categorical_accuracy: 0.9088 - val_loss: 1.2944 - val_accuracy: 0.6600 - val_top_k_categorical_accuracy: 0.8380
# Epoch 77/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8524 - accuracy: 0.7467 - top_k_categorical_accuracy: 0.9077 - val_loss: 1.2761 - val_accuracy: 0.6566 - val_top_k_categorical_accuracy: 0.8406
# Epoch 78/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8434 - accuracy: 0.7474 - top_k_categorical_accuracy: 0.9088 - val_loss: 1.2846 - val_accuracy: 0.6582 - val_top_k_categorical_accuracy: 0.8444
# Epoch 79/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8460 - accuracy: 0.7426 - top_k_categorical_accuracy: 0.9090 - val_loss: 1.2728 - val_accuracy: 0.6596 - val_top_k_categorical_accuracy: 0.8434
# Epoch 80/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8341 - accuracy: 0.7483 - top_k_categorical_accuracy: 0.9095 - val_loss: 1.2936 - val_accuracy: 0.6570 - val_top_k_categorical_accuracy: 0.8402
# Epoch 81/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8290 - accuracy: 0.7491 - top_k_categorical_accuracy: 0.9110 - val_loss: 1.2963 - val_accuracy: 0.6578 - val_top_k_categorical_accuracy: 0.8420
# Epoch 82/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8206 - accuracy: 0.7541 - top_k_categorical_accuracy: 0.9130 - val_loss: 1.2851 - val_accuracy: 0.6618 - val_top_k_categorical_accuracy: 0.8430
# Epoch 83/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8207 - accuracy: 0.7524 - top_k_categorical_accuracy: 0.9130 - val_loss: 1.2797 - val_accuracy: 0.6610 - val_top_k_categorical_accuracy: 0.8412
# Epoch 84/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8215 - accuracy: 0.7520 - top_k_categorical_accuracy: 0.9116 - val_loss: 1.2818 - val_accuracy: 0.6600 - val_top_k_categorical_accuracy: 0.8424
# Epoch 85/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8239 - accuracy: 0.7506 - top_k_categorical_accuracy: 0.9119 - val_loss: 1.2805 - val_accuracy: 0.6620 - val_top_k_categorical_accuracy: 0.8422
# Epoch 86/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8259 - accuracy: 0.7523 - top_k_categorical_accuracy: 0.9113 - val_loss: 1.2789 - val_accuracy: 0.6604 - val_top_k_categorical_accuracy: 0.8408
# Epoch 87/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8154 - accuracy: 0.7565 - top_k_categorical_accuracy: 0.9138 - val_loss: 1.2813 - val_accuracy: 0.6602 - val_top_k_categorical_accuracy: 0.8398
# Epoch 88/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8141 - accuracy: 0.7536 - top_k_categorical_accuracy: 0.9128 - val_loss: 1.2746 - val_accuracy: 0.6620 - val_top_k_categorical_accuracy: 0.8408
# Epoch 89/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8220 - accuracy: 0.7514 - top_k_categorical_accuracy: 0.9116 - val_loss: 1.2738 - val_accuracy: 0.6618 - val_top_k_categorical_accuracy: 0.8418
# Epoch 90/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8163 - accuracy: 0.7534 - top_k_categorical_accuracy: 0.9121 - val_loss: 1.2807 - val_accuracy: 0.6628 - val_top_k_categorical_accuracy: 0.8412
# Epoch 91/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8096 - accuracy: 0.7556 - top_k_categorical_accuracy: 0.9154 - val_loss: 1.2757 - val_accuracy: 0.6634 - val_top_k_categorical_accuracy: 0.8414
# Epoch 92/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8144 - accuracy: 0.7529 - top_k_categorical_accuracy: 0.9123 - val_loss: 1.2762 - val_accuracy: 0.6622 - val_top_k_categorical_accuracy: 0.8410
# Epoch 93/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8163 - accuracy: 0.7524 - top_k_categorical_accuracy: 0.9125 - val_loss: 1.2790 - val_accuracy: 0.6622 - val_top_k_categorical_accuracy: 0.8400
# Epoch 94/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8136 - accuracy: 0.7558 - top_k_categorical_accuracy: 0.9134 - val_loss: 1.2777 - val_accuracy: 0.6640 - val_top_k_categorical_accuracy: 0.8416
# Epoch 95/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8147 - accuracy: 0.7563 - top_k_categorical_accuracy: 0.9138 - val_loss: 1.2729 - val_accuracy: 0.6628 - val_top_k_categorical_accuracy: 0.8410
# Epoch 96/150
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.8162 - accuracy: 0.7542 - top_k_categorical_accuracy: 0.9128 - val_loss: 1.2793 - val_accuracy: 0.6612 - val_top_k_categorical_accuracy: 0.8406

# %%
pd.DataFrame(history.history).plot()
plt.show()

# %%
model.evaluate(test_generator)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 1.2476 - accuracy: 0.6698 - top_k_categorical_accuracy: 0.8434
# [1.2475606203079224, 0.6697999835014343, 0.8434000015258789]

# %%
classnames = ['apple', 'aquarium_fish', 'baby', 'bear', 'beaver',
              'bed', 'bee', 'beetle', 'bicycle', 'bottle',
              'bowl', 'boy', 'bridge', 'bus', 'butterfly',
              'camel', 'can', 'castle', 'caterpillar', 'cattle',
              'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach',
              'couch', 'crab', 'crocodile', 'cup', 'dinosaur', 
              'dolphin', 'elephant', 'flatfish', 'forest', 'fox',
              'girl', 'hamster', 'house', 'kangaroo', 'computer_keyboard',
              'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 
              'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain',
              'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid',
              'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree',
              'plain', 'plate', 'poppy', 'porcupine', 'possum',
              'rabbit', 'raccoon', 'ray', 'road', 'rocket',
              'rose', 'sea', 'seal', 'shark', 'shrew', 
              'skunk', 'skyscraper', 'snail', 'snake', 'spider',
              'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table',
              'tank', 'telephone', 'television', 'tiger', 'tractor',
              'train', 'trout', 'tulip', 'turtle', 'wardrobe',
              'whale', 'willow_tree', 'wolf', 'woman', 'worm',]

# %%
batch = next(test_generator)

images = batch[0]
labels = batch[1]

fig = plt.figure(figsize=(10, 10))

for index, image in enumerate(images):
    ax = fig.add_subplot(6, 6, index+1)
    plt.imshow(image)
    
    image = np.expand_dims(image, 0)
    pred = model.predict(image)
    pred = np.squeeze(pred)
    
    label = np.argmax(labels[index])
    pred_index = np.argmax(pred)
    
    ax.set_title(f'Actual: {classnames[label]} \n Pred: {classnames[pred_index]}')
    ax.axis('off')
    
plt.tight_layout()
plt.show()
